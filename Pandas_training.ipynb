# %% [markdown]
# what is pandas?
# pandas is a pthon library used for analizing , cleaning and manipulating structured data in tabular form.

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
#import pandas
import  pandas as pd

# %%
pd.__version__#check installed pandas version
# Out:
# '2.2.2'

# %% [markdown]
# **what is data frame?**

# %% [markdown]
# A DataFrame in pandas is a 2-dimensional table-like data structure used to store and work with data.

# %% [markdown]
# 1. CREATE DATAFRAME

# %%
# Using a list
df = pd.DataFrame([11,22,33], columns=['col_Name'])
print(df)
# Out:
#    col_Name
# 0        11
# 1        22
# 2        33

# %%
print(type(df)) #check data type
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#using dictionary of lists
data = {'Name':['Madhav', 'Vishakha', 'Lalita', 'Hrishabh'],'age': [16,17,18,19],'salary':[90000, 70000, 80000,50000]}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#        Name  age  salary
# 0    Madhav   16   90000
# 1  Vishakha   17   70000
# 2    Lalita   18   80000
# 3  Hrishabh   19   50000

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# 2. BASIC DATAFRAME UNDERSTANDING

# %%
df.head(2) # top rows
# Out:
#        Name  age  salary
# 0    Madhav   16   90000
# 1  Vishakha   17   70000

# %%
df.tail(2) #last rows
# Out:
#        Name  age  salary
# 2    Lalita   18   80000
# 3  Hrishabh   19   50000

# %%
df.shape #return a tuple containingthe shape of the data frame - rows and columns
# Out:
# (4, 3)

# %%
df.columns #list of columns names in data frame
# Out:
# Index(['Name', 'age', 'salary'], dtype='object')

# %%
df.rename(columns={'salary': 'Monthly_salary'}, inplace=True) # rename column name/s

# %%
df
# Out:
#        Name  age  Monthly_salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           80000
# 3  Hrishabh   19           50000

# %%
df
# Out:
#        Name  age  Monthly_salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           80000
# 3  Hrishabh   19           50000

# %%
df.info() #info method prints information about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            4 non-null      object
#  1   age             4 non-null      int64
#  2   Monthly_salary  4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df.describe() #describe method generates descriptive statistics of dataframe,only for numerical values
# Out:
#              age  Monthly_salary
# count   4.000000        4.000000
# mean   17.500000    72500.000000
# std     1.290994    17078.251277
# min    16.000000    50000.000000
# 25%    16.750000    65000.000000
# 50%    17.500000    75000.000000
# 75%    18.250000    82500.000000
# max    19.000000    90000.000000

# %% [markdown]
# 3. SAVE AND LOAD DATA FROM CSV

# %%
df.to_csv('Test_data.csv', index=False) #save file- export data frame

# %%
load_df= pd.read_csv('Test_data.csv')# load file - import data frame
load_df
# Out:
#        Name  age  Monthly_salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           80000
# 3  Hrishabh   19           50000

# %% [markdown]
# 4. ROWS & COLUMNS - SELECTION

# %%
#SELECT single column
df[['Name']]
# Out:
#        Name
# 0    Madhav
# 1  Vishakha
# 2    Lalita
# 3  Hrishabh

# %%
#select multiple columns
df[['Name','Monthly_salary']]
# Out:
#        Name  Monthly_salary
# 0    Madhav           90000
# 1  Vishakha           70000
# 2    Lalita           80000
# 3  Hrishabh           50000

# %%
#select single row // loc - Lable based index
df.loc[df.Name=='Madhav']
# Out:
#      Name  age  Monthly_salary
# 0  Madhav   16           90000

# %% [markdown]
# 5. FILTER  DATAFRAME

# %%
df
# Out:
#        Name  age  Monthly_salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           80000
# 3  Hrishabh   19           50000

# %%
df_age_filter = df[df['age'] >= 18] #filter and store dataframe in a new variable
df_age_filter
# Out:
#        Name  age  Monthly_salary
# 2    Lalita   18           80000
# 3  Hrishabh   19           50000

# %%
df_age_filter
# Out:
#        Name  age  Monthly_salary
# 2    Lalita   18           80000
# 3  Hrishabh   19           50000

# %%
df[(df['age'] >= 18) & (df['Monthly_salary'] >= 50000)] # multiple filter condition
# Out:
#        Name  age  Monthly_salary
# 2    Lalita   18           80000
# 3  Hrishabh   19           50000

# %%
df.where(df['age'] >= 18) #where function replace values in a dataframe based on a condition
# Out:
#        Name   age  Monthly_salary
# 0       NaN   NaN             NaN
# 1       NaN   NaN             NaN
# 2    Lalita  18.0         80000.0
# 3  Hrishabh  19.0         50000.0

# %%
df.where(df['age'] >= 18, other = 'Not Eligible')
# Out:
#            Name           age Monthly_salary
# 0  Not Eligible  Not Eligible   Not Eligible
# 1  Not Eligible  Not Eligible   Not Eligible
# 2        Lalita            18          80000
# 3      Hrishabh            19          50000

# %% [markdown]
# 6. ROW AND COLUMN - OPERATION (ADD, update , delete)

# %%
df
# Out:
#        Name  age  Monthly_salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           80000
# 3  Hrishabh   19           50000

# %%
#create a new column
df['team'] = ['CEO', 'HR', 'CTO', 'DA']
df
# Out:
#        Name  age  Monthly_salary team
# 0    Madhav   16           90000  CEO
# 1  Vishakha   17           70000   HR
# 2    Lalita   18           80000  CTO
# 3  Hrishabh   19           50000   DA

# %%
#add new column using existing column/s
df['Bonus'] = df['Monthly_salary'] * 0.20
df
# Out:
#        Name  age  Monthly_salary team    Bonus
# 0    Madhav   16           90000  CEO  18000.0
# 1  Vishakha   17           70000   HR  14000.0
# 2    Lalita   18           80000  CTO  16000.0
# 3  Hrishabh   19           50000   DA  10000.0

# %%
#add new row - at the end of data frame
df.loc[len(df)] = ['ABC', 21, 21000, 'IT', 2000]
df
# Out:
#        Name  age  Monthly_salary team    Bonus
# 0    Madhav   16           90000  CEO  18000.0
# 1  Vishakha   17           70000   HR  14000.0
# 2    Lalita   18           80000  CTO  16000.0
# 3  Hrishabh   19           50000   DA  10000.0
# 4       ABC   21           21000   IT   2000.0

# %%
#update value in dataframe using index-name
df.loc[0, 'Monthly_salary'] = 95000
df
# Out:
#        Name  age  Monthly_salary team    Bonus
# 0    Madhav   16           95000  CEO  18000.0
# 1  Vishakha   17           70000   HR  14000.0
# 2    Lalita   18           80000  CTO  16000.0
# 3  Hrishabh   19           50000   DA  10000.0
# 4       ABC   21           21000   IT   2000.0

# %%
#update value in dataframe using column-value
df.loc[df.Name=='Madhav','Monthly_salary'] = 90000
df
# Out:
#        Name  age  Monthly_salary team    Bonus
# 0    Madhav   16           90000  CEO  18000.0
# 1  Vishakha   17           70000   HR  14000.0
# 2    Lalita   18           80000  CTO  16000.0
# 3  Hrishabh   19           50000   DA  10000.0
# 4       ABC   21           21000   IT   2000.0

# %%
#delete value - rows and columns

# %%
#delete row using column - value filter
df = df.drop(df[df.Name == 'ABC'].index) #delete row, axis=0

# %%
#delete row using index-name filter
df.drop(1, axis=0)
# Out:
#        Name  age  Monthly_salary team    Bonus
# 0    Madhav   16           90000  CEO  18000.0
# 2    Lalita   18           80000  CTO  16000.0
# 3  Hrishabh   19           50000   DA  10000.0

# %%
df.drop('Bonus', axis=1, inplace=True) #delete one columns
#df.drop(['Bonus', 'team], axis=1, inplace=True) #delete multiple columns

# %%
df
# Out:
#        Name  age  Monthly_salary team
# 0    Madhav   16           90000  CEO
# 1  Vishakha   17           70000   HR
# 2    Lalita   18           80000  CTO
# 3  Hrishabh   19           50000   DA

# %%
df.rename(columns={'Monthly_salary': 'salary'}, inplace=True) #rename column name

# %%
#sort values - order values in dataframe by asc or desc order
df.sort_values('salary') #ascending order , by default
# Out:
#        Name  age  salary team
# 3  Hrishabh   19   50000   DA
# 1  Vishakha   17   70000   HR
# 2    Lalita   18   80000  CTO
# 0    Madhav   16   90000  CEO

# %%
df.sort_values('salary') #ascending order , by default
# Out:
#        Name  age  salary team
# 3  Hrishabh   19   50000   DA
# 1  Vishakha   17   70000   HR
# 2    Lalita   18   80000  CTO
# 0    Madhav   16   90000  CEO

# %% [markdown]
# 7. WORKING WITH DATA VALUE

# %%
#create a  data column - data of joining
df['DOJ'] = ['2024-01-01', '2024-01-15', '2024-03-28', '2024-03-03']
df
# Out:
#        Name  age  salary team         DOJ
# 0    Madhav   16   90000  CEO  2024-01-01
# 1  Vishakha   17   70000   HR  2024-01-15
# 2    Lalita   18   80000  CTO  2024-03-28
# 3  Hrishabh   19   50000   DA  2024-03-03

# %%
df['DOJ'].dtype #object - type value
# Out:
# dtype('O')

# %%
df['DOJ'] = pd.to_datetime(df['DOJ']) #change to date- time type

# %%
df['DOJ'].dtype #date-time type
# Out:
# dtype('<M8[ns]')

# %%
df1=df

# %%
df['DOJ2'] = ['2024-01-02','2024-01-08','2024-05-30','2024-02-05']
df
# Out:
#        Name  age  salary team        DOJ        DOJ2
# 0    Madhav   16   90000  CEO 2024-01-01  2024-01-02
# 1  Vishakha   17   70000   HR 2024-01-15  2024-01-08
# 2    Lalita   18   80000  CTO 2024-03-28  2024-05-30
# 3  Hrishabh   19   50000   DA 2024-03-03  2024-02-05

# %%
df['DOJ']+ pd.Timedelta(days=90)#add 90 days to doj column
# Out:
# 0   2024-03-31
# 1   2024-04-14
# 2   2024-06-26
# 3   2024-06-01
# Name: DOJ, dtype: datetime64[ns]

# %% [markdown]
#  8. HANDLING MISSING VALUES

# %%
df
# Out:
#        Name  age  salary team        DOJ        DOJ2
# 0    Madhav   16   90000  CEO 2024-01-01  2024-01-02
# 1  Vishakha   17   70000   HR 2024-01-15  2024-01-08
# 2    Lalita   18   80000  CTO 2024-03-28  2024-05-30
# 3  Hrishabh   19   50000   DA 2024-03-03  2024-02-05

# %%
df.isnull() # detect missing value
# Out:
#     Name    age  salary   team    DOJ   DOJ2
# 0  False  False   False  False  False  False
# 1  False  False   False  False  False  False
# 2  False  False   False  False  False  False
# 3  False  False   False  False  False  False

# %%
import numpy as np # to create null values below

# %%
df.loc[df.Name== 'hrishabh','salary'] = np.nan
